# %% [markdown]
# # Знакомство с языком программирования Python

# %% [markdown]
# # Рейтинг Tiobe

# %% [markdown]
# <img src='Tiobe_table.jpg' width=640, heigth=480>

# %% [markdown]
# <img src='Tiobe_graph.jpg' width=640, heigth=480>

# %% [markdown]
# # IEEE Spectrum’s Top Programming Languages 2024

# %% [markdown]
# <img src='IEEE.jpg' width=640, heigth=480>

# %% [markdown]
# # Достоинства

# %% [markdown]
# * Качество программного обеспечения
# * Высокая скорость разработки
# * Переносимость программ
# * Библиотеки поддержки
# * Интеграция компонентов

# %% [markdown]
# # Философия

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# * Красивое лучше, чем уродливое.
# * Явное лучше, чем неявное.
# * Простое лучше, чем сложное.
# * Сложное лучше, чем запутанное.
# * Плоское лучше, чем вложенное.
# * Разреженное лучше, чем плотное.
# * Читаемость имеет значение.
# * Особые случаи не настолько особые, чтобы нарушать правила.
# * При этом практичность важнее безупречности.
# * Ошибки никогда не должны замалчиваться.
# * Если не замалчиваются явно.
# * Встретив двусмысленность, отбрось искушение угадать.
# * Должен существовать один – и, желательно, только один – очевидный способ сделать это.
# * Хотя он поначалу может быть и не очевиден, если вы не голландец.
# * Сейчас лучше, чем никогда.
# * Хотя никогда зачастую лучше, чем прямо сейчас.
# * Если реализацию сложно объяснить – идея плоха.
# * Если реализацию легко объяснить – идея, возможно, хороша.
# * Пространства имён – отличная вещь! Давайте будем делать их больше.

# %% [markdown]
# # Особенности синтаксиса

# %%
# комментарий однострочный
x = 1  # fghfdghf
'''
комментарий
многострочный
'''
x = 6
"""комментарий
многострочный"""
# Out:
# 'комментарий\nмногострочный'

# %%
"""комментарий
многострочный""";

# %%
x = 2; y = 3  # так лучше не делать!
print(x, y)
# Out:
# 2 3

# %%
if x == 1 or x == 2 \
or x == 3 or x == 4:
    print(x)
# Out:
# 2

# %%
if (x == 2 or x == 3
    or x == 4):
    print(x)
# Out:
# 2

# %%
if x==2: print(x)
# Out:
# 2

# %% [markdown]
# ## Переменные

# %%
s = 'something'
n = 2586573465873465879878998099374
v = 4.56

# %%
type(s)
# Out:
# str

# %%
type(n)
# Out:
# int

# %%
type(v)
# Out:
# float

# %%
n = n + 1
print(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-940570239.py in <cell line: 0>()
# ----> 1 n = n + 1
#       2 print(n)
#
# NameError: name 'n' is not defined

# %%
Вот классификация ключевых слов Python по категориям:

| Категория            | Ключевые слова                          | Описание                                                                 |
|----------------------|-----------------------------------------|--------------------------------------------------------------------------|
| **Условные операторы** | `if`, `elif`, `else`                    | Используются для ветвления логики программы                              |
| **Логические операторы** | `and`, `or`, `not`, `is`                | Для логических операций и сравнений                                      |
| **Циклы**            | `for`, `while`, `break`, `continue`     | Управление циклами и их прерыванием                                      |
| **Функции**          | `def`, `return`, `yield`, `lambda`      | Создание функций и генераторов                                           |
| **Классы**           | `class`, `pass`                         | Определение классов и заглушек                                           |
| **Исключения**       | `try`, `except`, `finally`, `raise`     | Обработка и вызов исключений                                             |
| **Импорт**           | `import`, `from`, `as`                  | Подключение модулей и пакетов                                            |
| **Области видимости** | `global`, `nonlocal`                    | Управление областями видимости переменных                                |
| **Управление памятью** | `del`                                   | Удаление объектов                                                        |
| **Контекстные менеджеры** | `with`                                | Управление ресурсами (файлы, соединения и т.д.)                          |
| **Асинхронность**    | `async`, `await`                        | Работа с асинхронным кодом                                               |
| **Отладка**          | `assert`                                | Проверка условий в режиме отладки                                        |
| **Специальные**      | `None`, `True`, `False`                 | Специальные константы                                                    |
| **Устаревшие**       | `exec`                                  | Исполнение строки как кода (не рекомендуется к использованию)            |
| **Функции (не ключ. слова)** | print                            | Встроенная функция вывода (не является ключевым словом)                  |

# %% [markdown]
# **Ключевые слова:**
#
#     and
#     elif
#     if
#     print
#     finally
#     try
#     del
#     global
#     pass
#     class
#     is
#     from
#     or
#     yield
#     exec
#     return
#     not
#     with
#     break
#     in
#     def
#     while
#     assert
#     except
#     raise
#     for
#     as
#     else
#     import
#     continue
#     lambda

# %%
and
elif
if
print
finally
try
del
global
pass
class
is
from
or
yield
exec
return
not
with
break
in
def
while
assert
except
raise
for
as
else
import
continue
lambda

# %% [markdown]
# ## Типы данных

# %% [markdown]
# ### Числа

# %%
n = 5
k = 5.9
print(n)
print(k)
# Out:
# 5
# 5.9

# %%
n = float(n)
k = int(k)
print(n)
print(k)
# Out:
# 5.0
# 5

# %% [markdown]
# ### Операции

# %% [markdown]
# x + y
#
# x − y
#
# x ∗ y
#
# x/y
#
# x//y
#
# x%y
#
# x∗∗y
#
# −x
#
# *Функции:*
#
# abs()
#
# pow()
#
# divmod()
#
# round()
#
# *Модули* math, random

# %%
print(100 / 8)
print(100 / 8.2)
# Out:
# 12.5
# 12.195121951219512

# %%
print(100 // 8)
print(101.8 // 12.5)
print(101.8 / 12.5)
# Out:
# 12
# 8.0
# 8.144

# %%
10 % 3
# Out:
# 1

# %%
2 ** 10
# Out:
# 1024

# %%
2.1**2.3
# Out:
# 5.509400928686412

# %%
divmod(17, 5)
# Out:
# (3, 2)

# %%
round(12.6)
# Out:
# 13

# %%
round(12.5)
# Out:
# 12

# %%
round(11.5)
# Out:
# 12

# %% [markdown]
# ## Логические переменные

# %% [markdown]
# * True, False
# * Операции и выражения:
#     - '>'
#     - <
#     - ==
#     - !=
#     - not x
#     - x and y
#     - x or y
#     - x in A
#     - a < x < b

# %%
2 < 3 < 4 < 5
# Out:
# True

# %% [markdown]
# ## Ввод и вывод данных

# %%
print('What is your name?')
k = input()
print('Hello,', k + '!')
# Out:
# What is your name?
# 2
# Hello, 2!

# %%
n = int(input())
print(f'{n}^2 = {n**2}')
# Out:
# 2
# 2^2 = 4

# %%
x = 25
y = 50
print(x, y)
print(x + y)
print(str(x) + ' ' + str(y))
print(f'{x} {y}')
print(f'x = {x}; y = {y}')
# Out:
# 25 50
# 75
# 25 50
# 25 50
# x = 25; y = 50

# %%
print(x, y, x, y)
print(x, y, x, y, sep='!')
print(x, y, x, y, sep=' ! ', end='*')
print(x, y, x, y)
# Out:
# 25 50 25 50
# 25!50!25!50
# 25 ! 50 ! 25 ! 50*25 50 25 50

# %% [markdown]
# # Ветвление и оператор выбора

# %%
if x > 0:
    print ('x is positive')


if x % 2 == 0:
    print('x is even')
else:
    print('x is odd')
# Out:
# x is positive
# x is odd

# %%
x
# Out:
# 25

# %%
if x < y:
    print('x is less than y')
elif x > y:
    print('x is greater than y')
else:
    print('x and y are equal')
# Out:
# x is less than y

# %%
if x == y:
    print('x and y are equal')
else:
    if x < y:
        print('x is less than y')
    else:
        print('x is greater than y')
# Out:
# x is less than y

# %%
X = 1
Y = 2
Z = 3

if X != 0:
    A = Y
else:
    A = Z

print(A)

# %%
X = 1
Y = 2
Z = 3

A = Y if X else Z  # Трехместное выражение if/else

print(A)
# Out:
# 2

# %% [markdown]
# Проверка истинности в Python:
#
# * Операции сравнения возвращают True или False
# * Любое число, не равное 0, или непустой объект – истина
# * Числа, равные 0, пустые объекты и значение None – ложь
# * Операции сравнения применяются к структурам данных рекурсивно

# %% [markdown]
# ## Цикл while

# %%
i = 5
while i < 15:
    print(i)
    #i = i + 2
    i += 2
print('!')
# Out:
# 5
# 7
# 9
# 11
# 13
# !

# %%
# имитация until
i = 5
while True:
    print(i)
    i += 2
    if i >= 15:
        break
print('!')
# Out:
# 5
# 7
# 9
# 11
# 13
# !

# %% [markdown]
# ## Цикл for

# %%
for i in 'hello world':
    print(i * 2, end = '')
# Out:
# hheelllloo  wwoorrlldd

# %%
s = 'hello world'
for i in range(len(s)):
    print(s[i] * 2, end = '')
# Out:
# hheelllloo  wwoorrlldd

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(3, 15, 2):
    print(i)
# Out:
# 3
# 5
# 7
# 9
# 11
# 13

# %%
for i in [1, 2, 3]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
list = [6, 2, 8]
for index, el in enumerate(list):
    print(index, el)
# Out:
# 0 6
# 1 2
# 2 8

# %%
list = [6, 2, 8]
for index, el in enumerate(list, start = 1):
    print(index, el)
# Out:
# 1 6
# 2 2
# 3 8

# %%
l = []

# %%
l
# Out:
# []

# %% [markdown]
# ## Оператор continue

# %%
for i in 'hello world':
    if i == 'o':
        continue
    print(i * 2, end='')
# Out:
# hheellll  wwrrlldd

# %% [markdown]
# ## Оператор break

# %%
for i in 'hello world':
    if i == 'o':
        break
    print(i * 2, end='')
# Out:
# hheellll

# %% [markdown]
# ## Еlse в цикле

# %%
for i in 'hello world':
    if i == 'a':
        break
else: # если выход из цикла произошел без помощи break
    print('Буквы a в строке нет')
# Out:
# Буквы a в строке нет

# %% [markdown]
# ## Инструкция pass

# %% [markdown]
# Не выполняет никаких действий и используется в случаях, когда синтаксис языка требует наличия инструкции, но никаких полезных действий в этой точке программы выполнять нельзя.

# %%
x = 4
if x==5:
    pass
else:
    print('yes')
# Out:
# yes
